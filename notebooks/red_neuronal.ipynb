# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import json
import seaborn as sns

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %%
df = pd.read_csv('../data/breast_cancer.csv')
X = df.drop('target', axis=1)
y = df['target']

# %%
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean_fractal_dimension  ...  worst_texture  worst_perimeter  worst_area  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
mlp = MLPClassifier(max_iter=1000)

param_grid = {
    'hidden_layer_sizes': [(32,), (64,), (128,), (256,), (512,)],
    'activation': ['tanh', 'relu'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.001, 0.01, 0.1],
}

grid_search = RandomizedSearchCV(mlp,
                                 param_grid,
                                 cv=3,
                                 scoring='accuracy',
                                 n_jobs=-1)

grid_search.fit(X_train_scaled, y_train)

best_model = grid_search.best_estimator_

print("Mejores hiperparámetros:", grid_search.best_params_)

y_pred = best_model.predict(X_test_scaled)
# Out:
# Mejores hiperparámetros: {'solver': 'sgd', 'hidden_layer_sizes': (64,), 'alpha': 0.01, 'activation': 'tanh'}

# %%
cm = confusion_matrix(y_test, y_pred)

# Etiquetas
labels = ["Maligno", "Benigno"]

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,         
    fmt="d",         
    cmap="Blues",    
    xticklabels=labels,
    yticklabels=labels,
    cbar=True              
)

plt.title("Matriz de Confusión")
plt.xlabel("Predicho")
plt.ylabel("Real")

plt.tight_layout()
plt.show()

# %%
exactitud = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Exactitud:", exactitud * 100, "%")
print("Precision:", precision * 100, "%")
print("Recall:   ", recall * 100, "%")
print("F1-Score: ", f1 * 100, "%")
# Out:
# Exactitud: 97.07602339181285 %
# Precision: 97.11538461538461 %
# Recall:    98.05825242718447 %
# F1-Score:  97.58454106280193 %

# %%
metrics = {
    "accuracy": float(exactitud),
    "precision": float(precision),
    "recall": float(recall),
    "f1_score": float(f1),
    "confusion_matrix": cm.tolist()

}

with open("../models/nn_metrics.json", "w") as f:
    json.dump(metrics, f)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.savefig("../frontend/static/cm_neural_network.png")
plt.close()

print("Métricas guardadas")
# Out:
# Métricas guardadas

# %%
joblib.dump(best_model, '../models/neural_network.pkl')
# Out:
# ['../models/neural_network.pkl']
